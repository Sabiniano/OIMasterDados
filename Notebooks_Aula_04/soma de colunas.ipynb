# %%
import pandas as pd
import numpy as np
import time

# %%
# Importando a tabela do Excel
s = time.time()
indsocdem=pd.read_excel("Indicadores Socio-Demograficos.xlsx", sheet_name="BASE_DADOS")
e = time.time()
print("Tempo de leitura foi de:", e - s)
indsocdem.head(3)
# Out:
# Tempo de leitura foi de: 1.408707618713379
#                 CIDADE ESTADO  IBGE_RES_POP  IBGE_POP_URB  POP_ABAIXO_1  \
# 0      Abadia De Goiás     GO        6876.0        5300.0          69.0
# 1  Abadia Dos Dourados     MG        6704.0        4154.0          38.0
# 2            Abadiânia     GO       15757.0       10656.0         139.0
#
#    POP_1_4  POP_5_9  POP_10-14  POP_15-59  POP_60_MAIS  ...  IDHM_Educacao  \
# 0    318.0    438.0      517.0     3542.0        416.0  ...          0.622
# 1    207.0    260.0      351.0     2709.0        589.0  ...          0.563
# 2    650.0    894.0     1087.0     6896.0        990.0  ...          0.579
#
#         LONG        LAT  TV_CABO  POP_ESTIMADA        PIB  PIB_CAPITA  CARROS  \
# 0 -49.440548 -16.758812    360.0        8583.0     166.41    20664.57  2158.0
# 1 -47.396832 -18.487565     77.0        6972.0     180.09    25591.70  2227.0
# 2 -48.718812 -16.182672    227.0       19614.0  287984.49    15628.40  2838.0
#
#     MOTOS  TOT_EMPRESAS
# 0  1246.0         284.0
# 1  1142.0         476.0
# 2  1426.0         288.0
#
# [3 rows x 23 columns]

# %%
indsocdem.columns
# Out:
# Index(['CIDADE', 'ESTADO', 'IBGE_RES_POP', 'IBGE_POP_URB', 'POP_ABAIXO_1',
#        'POP_1_4', 'POP_5_9', 'POP_10-14', 'POP_15-59', 'POP_60_MAIS', 'IDHM',
#        'IDHM_Renda', 'IDHM_Longevidade', 'IDHM_Educacao', 'LONG', 'LAT',
#        'TV_CABO', 'POP_ESTIMADA', 'PIB', 'PIB_CAPITA', 'CARROS', 'MOTOS',
#        'TOT_EMPRESAS'],
#       dtype='object')

# %%
indsocdem['populacao ate 14'] = indsocdem['POP_ABAIXO_1'] + indsocdem['POP_1_4'] + indsocdem['POP_5_9'] + indsocdem['POP_10-14']
indsocdem['% ate 14'] = (indsocdem['populacao ate 14'] / indsocdem['POP_ESTIMADA']) * 100
indsocdem['% >= 60'] = (indsocdem['POP_60_MAIS'] / indsocdem['POP_ESTIMADA']) * 100
indsocdem.head(3)
# Out:
#                 CIDADE ESTADO  IBGE_RES_POP  IBGE_POP_URB  POP_ABAIXO_1  \
# 0      Abadia De Goiás     GO        6876.0        5300.0          69.0
# 1  Abadia Dos Dourados     MG        6704.0        4154.0          38.0
# 2            Abadiânia     GO       15757.0       10656.0         139.0
#
#    POP_1_4  POP_5_9  POP_10-14  POP_15-59  POP_60_MAIS  ...  TV_CABO  \
# 0    318.0    438.0      517.0     3542.0        416.0  ...    360.0
# 1    207.0    260.0      351.0     2709.0        589.0  ...     77.0
# 2    650.0    894.0     1087.0     6896.0        990.0  ...    227.0
#
#    POP_ESTIMADA        PIB  PIB_CAPITA  CARROS   MOTOS  TOT_EMPRESAS  \
# 0        8583.0     166.41    20664.57  2158.0  1246.0         284.0
# 1        6972.0     180.09    25591.70  2227.0  1142.0         476.0
# 2       19614.0  287984.49    15628.40  2838.0  1426.0         288.0
#
#    populacao ate 14   % ate 14   % >= 60
# 0            1342.0  15.635559  4.846790
# 1             856.0  12.277682  8.448078
# 2            2770.0  14.122566  5.047415
#
# [3 rows x 26 columns]
