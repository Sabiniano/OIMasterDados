# %%
import pandas as pd
import time
s = time.time()
df = pd.read_excel("Ano-2017.xlsx", engine='openpyxl', sheet_name = "Ano-2017")
e = time.time()
print("Tempo de processamento pandas = {}".format(e - s))
# Out:
# Tempo de processamento pandas = 197.31005764007568

# %%
df.head()
# Out:
#   txNomeParlamentar  cpf  ideCadastro  nuCarteiraParlamentar  nuLegislatura  \
# 0        LID.GOV-CD  NaN          NaN                    NaN         2015.0
# 1        LID.GOV-CD  NaN          NaN                    NaN         2015.0
# 2        LID.GOV-CD  NaN          NaN                    NaN         2015.0
# 3        LID.GOV-CD  NaN          NaN                    NaN         2015.0
# 4        LID.GOV-CD  NaN          NaN                    NaN         2015.0
#
#   sgUF sgPartido  codLegislatura  numSubCota  \
# 0  NaN       NaN            55.0         1.0
# 1  NaN       NaN            55.0         1.0
# 2  NaN       NaN            55.0         9.0
# 3  NaN       NaN            55.0         9.0
# 4  NaN       NaN            55.0        13.0
#
#                                         txtDescricao  ...  numAno numParcela  \
# 0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...  ...  2017.0        0.0
# 1  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...  ...  2017.0        0.0
# ...
